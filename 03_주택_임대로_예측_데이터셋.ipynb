# %% [markdown]
# # **1. 주택 임대료 예측 데이터셋**
# House Rent Prediction Dataset은 주택 임대료를 예측하기 위한 목적으로 사용되는 데이터셋입니다. 이 데이터셋은 주로 머신러닝 및 데이터 분석 프로젝트에서 사용되며, 주택의 다양한 특성과 위치 정보를 기반으로 임대료를 예측하는 모델을 학습하는 데 활용됩니다.
#
# https://www.kaggle.com/datasets/iamsouravbanerjee/house-rent-prediction-dataset/data?select=House_Rent_Dataset.csv

# %% [markdown]
# # **2. 데이터셋 컬럼**
#
# - BHK: 주택에 포함된 침실, 거실, 주방의 총 개수를 의미합니다.
# - Rent: 주택(아파트/플랫)의 월 임대료를 나타냅니다.
# - Size: 주택(아파트/플랫)의 면적을 평방피트(Square Feet)로 나타냅니다.
# - Floor: 주택이 위치한 층수와 건물의 총 층수를 나타냅니다. (예: 2층 중 1층, 5층 중 3층 등)
# - Area Type: 주택의 면적이 어떤 방식으로 계산되었는지를 나타냅니다. (예: 전체 면적, 실사용 면적, 건축 면적 등)
# - Area Locality: 주택(아파트/플랫)이 위치한 구체적인 지역이나 동네 정보를 나타냅니다.
# - City: 주택(아파트/플랫)이 위치한 도시를 나타냅니다.
# - Furnishing Status: 주택이 가구가 완비되었는지(Furnished), 부분적으로 갖추어졌는지(Semi-Furnished), 아니면 비어 있는지(Unfurnished)를 나타냅니다.
# - Tenant Preferred: 집주인 또는 중개인이 선호하는 임차인 유형을 나타냅니다. (예: 가족, 싱글, 직장인 등)
# - Bathroom: 주택에 있는 욕실의 개수를 나타냅니다.
# - Point of Contact: 주택(아파트/플랫)에 대한 추가 정보를 얻기 위해 연락해야 할 담당자나 중개인의 정보를 나타냅니다.

# %%
import pandas as pd

# %%
rent_df = pd.read_csv('data/House_Rent_Dataset.csv')
rent_df
# Out:
#        Posted On  BHK   Rent  Size            Floor    Area Type  \
# 0     2022-05-18    2  10000  1100  Ground out of 2   Super Area
# 1     2022-05-13    2  20000   800       1 out of 3   Super Area
# 2     2022-05-16    2  17000  1000       1 out of 3   Super Area
# 3     2022-07-04    2  10000   800       1 out of 2   Super Area
# 4     2022-05-09    2   7500   850       1 out of 2  Carpet Area
# ...          ...  ...    ...   ...              ...          ...
# 4741  2022-05-18    2  15000  1000       3 out of 5  Carpet Area
# 4742  2022-05-15    3  29000  2000       1 out of 4   Super Area
# 4743  2022-07-10    3  35000  1750       3 out of 5  Carpet Area
# 4744  2022-07-06    3  45000  1500     23 out of 34  Carpet Area
# 4745  2022-05-04    2  15000  1000       4 out of 5  Carpet Area
#
#                  Area Locality       City Furnishing Status  Tenant Preferred  \
# 0                       Bandel    Kolkata       Unfurnished  Bachelors/Family
# ...

# %%
rent_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4746 entries, 0 to 4745
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Posted On          4746 non-null   str
#  1   BHK                4746 non-null   int64
#  2   Rent               4746 non-null   int64
#  3   Size               4746 non-null   int64
#  4   Floor              4746 non-null   str
#  5   Area Type          4746 non-null   str
#  6   Area Locality      4746 non-null   str
#  7   City               4746 non-null   str
#  8   Furnishing Status  4746 non-null   str
#  9   Tenant Preferred   4746 non-null   str
#  10  Bathroom           4746 non-null   int64
#  11  Point of Contact   4746 non-null   str
# dtypes: int64(4), str(8)
# memory usage: 445.1 KB

# %%
rent_df.describe()
# Out:
#                BHK          Rent         Size     Bathroom
# count  4746.000000  4.746000e+03  4746.000000  4746.000000
# mean      2.083860  3.499345e+04   967.490729     1.965866
# std       0.832256  7.810641e+04   634.202328     0.884532
# min       1.000000  1.200000e+03    10.000000     1.000000
# 25%       2.000000  1.000000e+04   550.000000     1.000000
# 50%       2.000000  1.600000e+04   850.000000     2.000000
# 75%       3.000000  3.300000e+04  1200.000000     2.000000
# max       6.000000  3.500000e+06  8000.000000    10.000000

# %%
round(rent_df.describe(), 2)
# Out:
#            BHK        Rent     Size  Bathroom
# count  4746.00     4746.00  4746.00   4746.00
# mean      2.08    34993.45   967.49      1.97
# std       0.83    78106.41   634.20      0.88
# min       1.00     1200.00    10.00      1.00
# 25%       2.00    10000.00   550.00      1.00
# 50%       2.00    16000.00   850.00      2.00
# 75%       3.00    33000.00  1200.00      2.00
# max       6.00  3500000.00  8000.00     10.00

# %%
rent_df['BHK']
# Out:
# 0       2
# 1       2
# 2       2
# 3       2
# 4       2
#        ..
# 4741    2
# 4742    3
# 4743    3
# 4744    3
# 4745    2
# Name: BHK, Length: 4746, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns # pip install seaborn

# %%
plt.rcParams['font.family'] = 'Malgun Gothic'

# %%
sns.displot(rent_df['BHK'])
plt.title("BHK 분포")
plt.show()

# %%
sns.displot(rent_df['Rent'])
plt.title("임대료 분포")
plt.show()

# %%
rent_df['Rent'].sort_values() # 오름차순
# Out:
# 4076       1200
# 285        1500
# 471        1800
# 2475       2000
# 146        2200
#          ...
# 1459     700000
# 1329     850000
# 827     1000000
# 1001    1200000
# 1837    3500000
# Name: Rent, Length: 4746, dtype: int64

# %%
sns.displot(rent_df['Size'])
plt.title("Size 분포")
plt.show()

# %%
rent_df['Size'].sort_values()
# Out:
# 4653      10
# 116       20
# 2973      25
# 3922      25
# 2460      25
#         ...
# 1001    5000
# 2048    5700
# 3622    6000
# 4457    7000
# 4185    8000
# Name: Size, Length: 4746, dtype: int64

# %% [markdown]
# ### boxplot
#
# Boxplot은 데이터의 중앙값, 사분위수, 이상치 등을 시각적으로 표현하는 통계 그래프입니다. 주로 데이터 분포와 이상치를 빠르게 파악하기 위해 사용됩니다.
#
# 1. 중앙값 (Median, Q2): 데이터를 크기 순으로 정렬했을 때 중간에 위치한 값
#
# 2. Q1 (제1사분위수, 25%): 하위 25%에 해당하는 값
#
# 3. Q3 (제3사분위수, 75%): 상위 25%에 해당하는 값
#
# 4. IQR (Interquartile Range, 사분위 범위): Q3 - Q1, IQR은 데이터의 중간 50% 범위를 의미합니다.
#
# 5. Minimum: Q1 − 1.5 × IQR 이하에 속하지 않는 가장 작은 값
#
# 6. Maximum: Q3 + 1.5 × IQR 이하에 속하지 않는 가장 큰 값
#
# 7. 이상치: 일반적인 데이터 분포를 벗어난 값(Lower Bound=Q1−1.5×IQR, Upper Bound=Q3+1.5×IQR)
#
# ( IQR 기준으로 이상치를 정의하기 때문에 모든 상황에 완벽하지 않을 수 있습니다)

# %%
sns.boxplot(rent_df['Rent'])
# Out:
# <Axes: ylabel='Rent'>

# %%
sns.boxplot(rent_df['Size'])
# Out:
# <Axes: ylabel='Size'>

# %%
sns.boxplot(rent_df['BHK'])
# Out:
# <Axes: ylabel='BHK'>

# %%
rent_df.isna().sum()
# Out:
# Posted On            0
# BHK                  0
# Rent                 0
# Size                 0
# Floor                0
# Area Type            0
# Area Locality        0
# City                 0
# Furnishing Status    0
# Tenant Preferred     0
# Bathroom             0
# Point of Contact     0
# dtype: int64

# %%
rent_df.isna().mean()
# Out:
# Posted On            0.0
# BHK                  0.0
# Rent                 0.0
# Size                 0.0
# Floor                0.0
# Area Type            0.0
# Area Locality        0.0
# City                 0.0
# Furnishing Status    0.0
# Tenant Preferred     0.0
# Bathroom             0.0
# Point of Contact     0.0
# dtype: float64

# %%
rent_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4746 entries, 0 to 4745
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Posted On          4746 non-null   str
#  1   BHK                4746 non-null   int64
#  2   Rent               4746 non-null   int64
#  3   Size               4746 non-null   int64
#  4   Floor              4746 non-null   str
#  5   Area Type          4746 non-null   str
#  6   Area Locality      4746 non-null   str
#  7   City               4746 non-null   str
#  8   Furnishing Status  4746 non-null   str
#  9   Tenant Preferred   4746 non-null   str
#  10  Bathroom           4746 non-null   int64
#  11  Point of Contact   4746 non-null   str
# dtypes: int64(4), str(8)
# memory usage: 445.1 KB

# %%
rent_df['Area Type'].unique()
# Out:
# <StringArray>
# ['Super Area', 'Carpet Area', 'Built Area']
# Length: 3, dtype: str

# %%
rent_df['Area Type'].nunique()
# Out:
# 3

# %%
for i in ['Posted On', 'Floor', 'Area Type', 'Area Locality', 'City', 'Furnishing Status', 'Tenant Preferred', 'Point of Contact']:
    print(i, rent_df[i].nunique())
# Out:
# Posted On 81
# Floor 480
# Area Type 3
# Area Locality 2235
# City 6
# Furnishing Status 3
# Tenant Preferred 3
# Point of Contact 3

# %%
# pandas 버전에 따라 str이 아닌 object 타입으로 동작할 수 있음
rent_df.select_dtypes(include=['str']).columns
# Out:
# Index(['Posted On', 'Floor', 'Area Type', 'Area Locality', 'City',
#        'Furnishing Status', 'Tenant Preferred', 'Point of Contact'],
#       dtype='str')

# %%
str_cols = rent_df.select_dtypes(include=['str']).columns

for col in str_cols:
    print(col, rent_df[col].nunique())
# Out:
# Posted On 81
# Floor 480
# Area Type 3
# Area Locality 2235
# City 6
# Furnishing Status 3
# Tenant Preferred 3
# Point of Contact 3

# %%
# Posted On
rent_df['Posted On'] = pd.to_datetime(rent_df['Posted On'])
rent_df['Posted_Year'] = rent_df['Posted On'].dt.year
rent_df['Posted_Month'] = rent_df['Posted On'].dt.month
rent_df['Posted_DayOfWeek'] = rent_df['Posted On'].dt.day_of_week

# %%
rent_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4746 entries, 0 to 4745
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Posted On          4746 non-null   datetime64[us]
#  1   BHK                4746 non-null   int64
#  2   Rent               4746 non-null   int64
#  3   Size               4746 non-null   int64
#  4   Floor              4746 non-null   str
#  5   Area Type          4746 non-null   str
#  6   Area Locality      4746 non-null   str
#  7   City               4746 non-null   str
#  8   Furnishing Status  4746 non-null   str
#  9   Tenant Preferred   4746 non-null   str
#  10  Bathroom           4746 non-null   int64
#  11  Point of Contact   4746 non-null   str
#  12  Posted_Year        4746 non-null   int32
#  13  Posted_Month       4746 non-null   int32
#  14  Posted_DayOfWeek   4746 non-null   int32
# dtypes: datetime64[us](1), int32(3), int64(4), str(7)
# memory usage: 500.7 KB

# %%
# Floor  480개
# rent_df['Floor']

# r' : Raw String(원시 문자열)
# (?P<name>\d+): 숫자를 찾고 그 결과를 컬럼 이름을 name으로 붙임
# 3 out of 10: Current_Floor 3, Total_Floors 10
# Ground out of 2 : Current_Floor Ground, Total_Floors 2

floor_pattern = (
    r'(?P<Current_Floor>Upper Basement|Lower Basement|Ground|Upper|Lower|Basement|\d+)'
    r'\s+out of\s+'
    r'(?P<Total_Floors>\d+)'
)

floor_split = rent_df['Floor'].astype(str).str.extract(floor_pattern)
floor_split
# Out:
#      Current_Floor Total_Floors
# 0           Ground            2
# 1                1            3
# 2                1            3
# 3                1            2
# 4                1            2
# ...            ...          ...
# 4741             3            5
# 4742             1            4
# 4743             3            5
# 4744            23           34
# 4745             4            5
#
# [4746 rows x 2 columns]

# %%
import numpy as np

# %%
# Upper Basement|Lower Basement|Ground|Upper|Lower|Basement

floor_map = {
    'Upper Basement': -1,
    'Lower Basement': -1,
    'Basement': -1,
    'Ground': 0,
    'Lower': 0,
    'Upper': np.nan
}

# %%
unmatched_floor_values = rent_df.loc[floor_split['Current_Floor'].isna(), 'Floor'].value_counts()
unmatched_floor_values
# Out:
# Floor
# 1         2
# 3         1
# Ground    1
# Name: count, dtype: int64

# %%
rent_df['Current_Floor'] = floor_split['Current_Floor'].replace(floor_map)
rent_df['Current_Floor'] = pd.to_numeric(rent_df['Current_Floor'],errors = 'coerce')
rent_df['Total_Floors'] = pd.to_numeric(floor_split['Total_Floors'],errors = 'coerce')

# %%
rent_df
# Out:
#       Posted On  BHK   Rent  Size            Floor    Area Type  \
# 0    2022-05-18    2  10000  1100  Ground out of 2   Super Area
# 1    2022-05-13    2  20000   800       1 out of 3   Super Area
# 2    2022-05-16    2  17000  1000       1 out of 3   Super Area
# 3    2022-07-04    2  10000   800       1 out of 2   Super Area
# 4    2022-05-09    2   7500   850       1 out of 2  Carpet Area
# ...         ...  ...    ...   ...              ...          ...
# 4741 2022-05-18    2  15000  1000       3 out of 5  Carpet Area
# 4742 2022-05-15    3  29000  2000       1 out of 4   Super Area
# 4743 2022-07-10    3  35000  1750       3 out of 5  Carpet Area
# 4744 2022-07-06    3  45000  1500     23 out of 34  Carpet Area
# 4745 2022-05-04    2  15000  1000       4 out of 5  Carpet Area
#
#                  Area Locality       City Furnishing Status  Tenant Preferred  \
# 0                       Bandel    Kolkata       Unfurnished  Bachelors/Family
# ...

# %%
# Upper는 정확한 층을 알 수 없으므로 Total_Floors값으로 보정
# 예: Upper out of 5: 5층 정도로 간주
upper_mask = floor_split['Current_Floor'].eq('Upper') & rent_df['Current_Floor'].isna()
rent_df.loc[upper_mask, 'Current_Floor'] = rent_df.loc[upper_mask, 'Total_Floors']

# %%
rent_df[['Floor', 'Current_Floor', 'Total_Floors']].head()
# Out:
#              Floor  Current_Floor  Total_Floors
# 0  Ground out of 2            0.0           2.0
# 1       1 out of 3            1.0           3.0
# 2       1 out of 3            1.0           3.0
# 3       1 out of 2            1.0           2.0
# 4       1 out of 2            1.0           2.0

# %%
# 추가 파생변수: 전체 층수 대비 현재 층의 위치
rent_df['Floor_Ratio'] = rent_df['Current_Floor'] / rent_df['Total_Floors']
rent_df['Floor_Ratio'] = rent_df['Floor_Ratio'].replace([np.inf, -np.inf], np.nan)
rent_df[['Floor', 'Current_Floor', 'Total_Floors', 'Floor_Ratio']].head()
# Out:
#              Floor  Current_Floor  Total_Floors  Floor_Ratio
# 0  Ground out of 2            0.0           2.0     0.000000
# 1       1 out of 3            1.0           3.0     0.333333
# 2       1 out of 3            1.0           3.0     0.333333
# 3       1 out of 2            1.0           2.0     0.500000
# 4       1 out of 2            1.0           2.0     0.500000

# %%
rent_df.drop(['Floor', 'Posted On'], axis = 1, inplace = True)

# %% [markdown]
# - Area Locality는 지역 정보이므로 범주형 변수로 사용
# - 전체 데이터에서 빈도 인코딩을 사용
# - train/test 정보가 섞이는 데이터 누수 가능성이 있음
# - 학습 데이터 기준으로 인코딩하도록 처리

# %%
X = rent_df.drop('Rent', axis = 1)  # X는 독립변수
y = rent_df['Rent'] # 종속변수

# %%
numeric_features = X.select_dtypes(include=['number']).columns.tolist()
print("숫자형 컬럼: ", numeric_features)

categorical_features = X.select_dtypes(include=['str','object', 'datetime', 'bool', 'category']).columns.tolist()
print('범주형 컬럼: ', categorical_features)

print('X 전체 결측치 개수: ', X.isna().sum().sum())
# Out:
# 숫자형 컬럼:  ['BHK', 'Size', 'Bathroom', 'Posted_Year', 'Posted_Month', 'Posted_DayOfWeek', 'Current_Floor', 'Total_Floors', 'Floor_Ratio']
# 범주형 컬럼:  ['Area Type', 'Area Locality', 'City', 'Furnishing Status', 'Tenant Preferred', 'Point of Contact']
# X 전체 결측치 개수:  12

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=2026)

# %% [markdown]
# # **3. Pipline**
# - 여러 작업을 정해진 순서대로 연결하는 객체
#
# ```
# 원본 데이터 -> 결측치 처리 -> 범주형 데이터 원-핫 인코딩 -> 모델 학습
#
# pipe = Pipline([
#     ('단계이름1', 변환기1),
#     ('단계이름2', 변환기2), ... ,
#     ('model', 모델)
# ])
# ```
#
# - 각 튜플의 첫 번쨰 값은 단계의 이름이고, 두 번째 값은 실제 작업을 수행할 객체
# - 예) ('imputer', SimpleImputer(strategy = 'median)) / imputer라는 이름으로 SimpleImputer를 등록함

# %% [markdown]
# ### Pipeline을 사용하는 이유
#
# ```
# X_train_imputed= imputer.fit_transform(X_train)
# X_train_encoded = encoder.fit_transform(X_train_imputed)
# model.fit(X_train_encoded, y_train)
# ```
#
# > 위 방식은 학습 데이터와 테스트 데이터에 서로 다른 처리가 적용되거나, 테스트 데이터까지 이용해 전처리 기준을 학습하는 실수를 만들기 쉬움
#
# Piplime을 사용하면 아래 한 줄로 전처리와 학습을 연결할 수 있음
# ```
# lr_model.fit(X_train, y_train)
# ```
#
# > Pipline의 핵심 장점은 단순히 코드가 짧아지는 것이 아니라, 학습과 예측에 동일한 전처리 규칙을 안저하게 적용하는 것

# %% [markdown]
# ### 숫자형 전처리 Pipeline
#
# ```
# # 숫자형 컬럼의 결측치를 각 컬럼의 중앙값으로 채움
# numeric_transformer = Pipeline([
#     ('imputer', SimpleImputer(strategy = 'median'))
# ])
# ```
#
# ### 범주형 전처리 Pipeline
# ```
# # 결측치를 가장 자주 등장한 값으로 채움 -> 문자열 범주를 원-핫 인코딩으로 숫자화함
# categorical_transformer = Pipeline([
#     ('imputer', SimpleImputer(strategy = 'most_frequent)),
#     ('onehot', OneHotEncoder(handle_unknown='ignore'))
# ])
# ```
#
# ### ColumsTransformer
# - 숫자형 컬럼과 범주형 컬럼은 같은 방법으로 처리할 수 없음
# - 예) 숫자형의 결측치는 중앙값으로 채울 수 있지만, 범주형 데이터는 중앙값을 적용할 수 없음
#
# ```
# preprocessor = ColumnTransformer([
#     ('num', numeric_transormer, numeric_features),
#     ('cat', categorical_transformer, categorical_features)
# ])
# ```
#
# ### 전체 Pipeline
# ```
# # preprocessor가 전체 전처리를 담당하고, 그 결과 LinearRegression 모델에 전달
# lr_model = Pipline([
#     ('preprocessor', preprocessor),
#     ('model', LinearRegression())
# ])
# ```
#
#
# ### fit()을 호출할 때 내부에서 일어나는 일
#
# ```
# lr_model.fit(X_train, y_train)
# ```
# 1. X_train의 숫자형 컬럼에서 중앙값을 계산함
# 2. X_train의 범주형 컬럼에서 최빈값을 계한함
# 3. X_train에 존재하는 범주 목록을 학습함
# 4. 전처리된 데이터를 하나의 숫자 행렬로 만듦
# 5. 그 결과로 회귀 모델을 학습함
#
# > 중앙값, 최빈값, 범주 목록을 오직 X_train에서만 학습한다는 것이 중요

# %% [markdown]
# ### predict()를 호출할 때 내부에서 일어나는 일
#
# ```
# pred = lr_model.predict(X_test)
# ```
# 1. 학습 때 저장한 숫자형 중앙값을 사용함
# 2. 학습 때 저장한 범주형 최빈값ㅇ르 사용함
# 3. 학습 때 만든 원-핫 인코딩 규칙을 사용함
# 4. 전처리 결과를 이미 학습된 모델에 넣어 예측함
#
# > 예측할 때는 새로운 중앙값이나 범주 목록을 다시 계산하지 않음. fit()은 기준으로 학습하고 저장하며, predict()는 저장된 기준을 그대로 사용함

# %% [markdown]
# ### 데이터 누수
# - 전체 데이터에서 먼저 전처리 기준으로 학습한 후 데이터를 나누는 것
